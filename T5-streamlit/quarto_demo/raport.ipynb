# %% [raw]
# ---
# title: "Python LevelUP: Data Science by Appsilon"
# subtitle: "Quarto Example"
# author: "Piotr Pasza Storożenko@Appsilon"
# lang: "en"
# self-contained: true
# ---

# %% [markdown]
# In this notebook we will explore the important function
#
# $$
# f(x) = \frac{\sin(x)}{x}
# $$ {#eq-sinus}
#
# Unfortunately equation labeling is not compatible with VS Code.

# %%
#| code-fold: true
# Note code folding
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#| echo: false
# And hiding

pd.set_option('display.max_rows', 50)
x = np.r_[0.000001:15:30j]
y = np.sin(x)/x
df = pd.DataFrame({'x':x, 'y':y})

# %%
#| label: fig-sinus
#| fig-cap: Plot of @eq-sinus
plt.figure(dpi=300)
plt.plot(x, y, '.')
plt.show()

# %% [markdown]
# The most important insight of @eq-sinus is presented at @fig-sinus. @tbl-sinus contains used data.

# %%
#| label: tbl-sinus
#| tbl-cap: "Experiment data"
#| echo: false

df
# Out:
#             x         y
# 0    0.000001  1.000000
# 1    0.517242  0.956003
# 2    1.034484  0.830945
# 3    1.551725  0.644327
# 4    2.068966  0.424588
# 5    2.586208  0.203878
# 6    3.103449  0.012288
# 7    3.620690 -0.127318
# 8    4.137932 -0.202876
# 9    4.655173 -0.214463
# 10   5.172414 -0.173235
# 11   5.689656 -0.098300
# 12   6.206897 -0.012279
# 13   6.724138  0.063473
# 14   7.241380  0.112983
# 15   7.758621  0.128303
# 16   8.275863  0.110239
# 17   8.793104  0.067155
# 18   9.310345  0.012264
# 19   9.827587 -0.039888
# 20  10.344828 -0.076911
# 21  10.862069 -0.091244
# 22  11.379311 -0.081488
# 23  11.896552 -0.052187
# 24  12.413793 -0.012243
# 25  12.931035  0.027580
# 26  13.448276  0.057402
# 27  13.965517  0.070553
# 28  14.482759  0.064965
# 29  15.000000  0.043353
